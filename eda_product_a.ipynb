# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.express as px
from plotly.offline import plot
from plotly.subplots import make_subplots

print('libraries imported!')
# Out:
# libraries imported!

# %%
# Importing product_a.csv dataset into pandas DataFrame with first column as index

df_product_a = pd.read_csv('product_a.csv', index_col=0)
df_product_a.head()
# Out:
#        date_w  price  total_vol     plu1       plu2    plu3   bags_t   bags_s  \
# 0  2016-12-24   1.33   64236.62  1036.74   54454.85   48.16  8696.87  8603.62
# 1  2016-12-17   1.35   54876.98   674.28   44638.81   58.33  9505.56  9408.07
# 2  2016-12-10   0.93  118220.22   794.70  109149.67  130.50  8145.35  8042.21
# 3  2016-12-03   1.08   78992.15  1132.00   71976.41   72.58  5811.16  5677.40
# 4  2016-11-26   1.28   51039.60   941.48   43838.39   75.78  6183.95  5986.26
#
#    bags_l  bags_lx type  year location
# 0   93.25      0.0    A  2015   Albany
# 1   97.49      0.0    A  2015   Albany
# 2  103.14      0.0    A  2015   Albany
# 3  133.76      0.0    A  2015   Albany
# 4  197.69      0.0    A  2015   Albany

# %%
# Converting date_w field to a suitable datetime data type

# Alternative code - df_product_a.date_w.astype('datetime64[ns]')
df_product_a['date_w'] = pd.to_datetime(df_product_a.date_w, format='%Y-%m-%d')
df_product_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_w     18249 non-null  datetime64[ns]
#  1   price      18249 non-null  float64
#  2   total_vol  18249 non-null  float64
#  3   plu1       18249 non-null  float64
#  4   plu2       18249 non-null  float64
#  5   plu3       18249 non-null  float64
#  6   bags_t     18249 non-null  float64
#  7   bags_s     18249 non-null  float64
#  8   bags_l     18249 non-null  float64
#  9   bags_lx    18249 non-null  float64
#  10  type       18249 non-null  object
#  11  year       18249 non-null  int64
#  12  location   18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
# Correcting 'year' field values

df_product_a['year'] = df_product_a.date_w.dt.year
df_product_a.head()
# Out:
#       date_w  price  total_vol     plu1       plu2    plu3   bags_t   bags_s  \
# 0 2016-12-24   1.33   64236.62  1036.74   54454.85   48.16  8696.87  8603.62
# 1 2016-12-17   1.35   54876.98   674.28   44638.81   58.33  9505.56  9408.07
# 2 2016-12-10   0.93  118220.22   794.70  109149.67  130.50  8145.35  8042.21
# 3 2016-12-03   1.08   78992.15  1132.00   71976.41   72.58  5811.16  5677.40
# 4 2016-11-26   1.28   51039.60   941.48   43838.39   75.78  6183.95  5986.26
#
#    bags_l  bags_lx type  year location
# 0   93.25      0.0    A  2016   Albany
# 1   97.49      0.0    A  2016   Albany
# 2  103.14      0.0    A  2016   Albany
# 3  133.76      0.0    A  2016   Albany
# 4  197.69      0.0    A  2016   Albany

# %%
# Descriptive statistical analysis of 'df_product_a'

# numeric columns to use
columns_to_include = ['price', 'total_vol', 'plu1', 'plu2', 'plu3', 'bags_t', 'bags_s', 'bags_l', 'bags_lx']

df_stats = df_product_a.describe(percentiles=[0.1, 0.2, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.75, 0.8, 0.9],
                                exclude=[np.object, np.int64, np.datetime64]).transpose()
# add columns - variance, median, mode
# NOTE: For mode, there is a tie between multiple values in 'total_vol' column, I am choosing one arbitrarily
df_stats['var'], df_stats['median'], df_stats['mode'] = df_product_a[columns_to_include].var(), df_product_a[columns_to_include].median(), df_product_a[columns_to_include].mode().iloc[0]
# add 'field_name' column to 'df_stats'
df_stats.index.name = 'field_name'
df_stats.reset_index(inplace=True)

df_stats
# Out:
#   field_name    count           mean           std    min       10%       20%  \
# 0      price  18249.0       1.405978  4.026766e-01   0.44     0.930     1.050
# 1  total_vol  18249.0  850644.013009  3.453545e+06  84.56  3896.768  8168.866
# 2       plu1  18249.0  293008.424531  1.264989e+06   0.00    94.276   483.362
# 3       plu2  18249.0  295154.568356  1.204120e+06   0.00   367.484  1918.532
# 4       plu3  18249.0   22839.735993  1.074641e+05   0.00     0.000     0.000
# 5     bags_t  18249.0  239639.202060  9.862424e+05   0.00  1299.208  3347.674
# 6     bags_s  18249.0  182194.686696  7.461785e+05   0.00   583.110  1686.086
# 7     bags_l  18249.0   54338.088145  2.439660e+05   0.00     0.000    30.918
# 8    bags_lx  18249.0    3106.426507  1.769289e+04   0.00     0.000     0.000
#
#         25%        30%        40%        50%         60%         70%  \
# 0      1.10      1.150      1.260       1.37       1.480       1.600
# 1  10838.58  15181.304  42137.088  107376.76  192430.124  319613.142
# 2    854.07   1368.118   3261.580    8645.30   31698.078   77991.410
# 3   3008.78   4265.508  10961.994   29061.02   53202.052   98296.168
# 4      0.00      0.000     42.704     184.99     768.782    3466.120
# 5   5088.64   7316.634  16643.260   39743.83   62361.468   88901.748
# 6   2849.42   4761.328  11502.076   26362.82   46725.754   68884.094
# 7    127.47    329.944   1105.110    2647.71    6087.796   14392.206
# 8      0.00      0.000      0.000       0.00       0.000      20.252
#
#          75%         80%          90%          max           var     median  \
# 0       1.66       1.740        1.930         3.25  1.621484e-01       1.37
# 1  432962.29  604868.968  1387045.760  62505646.52  1.192698e+13  107376.76
# 2  111020.20  152679.068   538385.184  22743616.17  1.600197e+12    8645.30
# 3  150206.86  222163.620   500784.552  20470572.61  1.449906e+12   29061.02
# 4    6243.42   10972.600    31492.442   2546439.11  1.154853e+10     184.99
# 5  110783.37  149306.360   442141.928  19373134.37  9.726741e+11   39743.83
# 6   83337.67  104537.112   354266.852  13384586.80  5.567824e+11   26362.82
# 7   22029.25   34350.986    94295.338   5719096.61  5.951939e+10    2647.71
# 8     132.50     557.114     3688.912    551693.65  3.130385e+08       0.00
#
#       mode
# 0     1.15
# 1  2038.99
# 2     0.00
# 3     0.00
# 4     0.00
# 5     0.00
# 6     0.00
# 7     0.00
# 8     0.00

# %%
# Creating a Pearson correlation matrix

df_coef_p = df_product_a.corr()
df_coef_p.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow0_col9 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col2 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col3 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col4 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col5 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col6 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col7 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col8 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow1_col9 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col1 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col3 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col4 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col5 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col6 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col7 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col8 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow2_col9 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col0 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col1 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col2 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col4 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col5 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col6 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col7 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col8 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow3_col9 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col1 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col3 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col5 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col6 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col7 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col8 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow4_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col1 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col2 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col3 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col4 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col6 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col7 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col8 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_2bc8d5dc_9a78_11ea_a75c_f82819cadecerow5_col9 {
#             background-color:  #5a78e4;
#             color:  #000000;

# %%
# Creating a Spearman Rank correlation matrix

df_coef_sp = df_product_a.corr(method='spearman')
df_coef_sp.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow0_col9 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col2 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col3 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col4 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col5 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col6 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col7 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col8 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow1_col9 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col1 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col3 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col4 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col5 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col6 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col7 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col8 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow2_col9 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col1 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col2 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col4 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col5 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col6 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col7 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col8 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow3_col9 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col1 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col2 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col3 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col5 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col6 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col7 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col8 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow4_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col1 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col2 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col3 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col4 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col6 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col7 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col8 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_2be24058_9a78_11ea_9b65_f82819cadecerow5_col9 {
#             background-color:  #89acfd;
#             color:  #000000;

# %%
# Create a Plotly scatter matrix plot for df_product_a

# What is 'trace' in plotly? 
# A trace is just the name we give a collection of data and the specifications of which we want that data plotted

fig = px.scatter_matrix(df_product_a.drop(['date_w'], axis=1), 
                        width=1500,
                        height=1500,
                        opacity=0.4, 
                        title='Scatter matrix plot for df_product_a'
                       )
fig.update_layout(title_x=0.5)
# open the figure in another tab as it is large in size
plot(fig, filename='scatter_matrix_plot.html')
# Out:
# 'scatter_matrix_plot.html'

# %%
# Creating weekly and monthly time-series graphs of the numeric fields

# convert the dataframe into a time-series format
df_product_a_ts = df_product_a.drop(['type', 'year', 'location'], axis=1).set_index('date_w').sort_index()

# downsample the data to weekly data points using average values for each week (weekly)
df_product_a_weekly = df_product_a_ts.resample('W').mean().dropna()
# downsample the data to monthly data points using average values for each month (monthly)
df_product_a_monthly = df_product_a_ts.resample('M').mean().dropna()

# creating traces
fig = make_subplots(rows=2, cols=1)

for col in df_product_a_ts.columns:
    # weekly
    fig.add_trace(go.Scatter(x=df_product_a_weekly.index, y=df_product_a_weekly[col],
                        mode='lines+markers',
                        name='{} weekly'.format(col)), row=1, col=1)
    
    # monthly
    fig.add_trace(go.Scatter(x=df_product_a_monthly.index, y=df_product_a_monthly[col],
                        mode='lines+markers',
                        name='{} monthly'.format(col)), row=2, col=1)

fig.update_layout(height=1400, title_text='Weekly and monthly time-series graphs', title_x=0.5)

plot(fig, filename='weekly_monthly_timeseries_graphs.html')
# Out:
# 'weekly_monthly_timeseries_graphs.html'

# %%
# Creating year based location and type bar charts for the total volume

# years to analyse
years = [2016, 2017, 2018, 2019]

# 4 subplots - one for each year
fig = make_subplots(rows=4, cols=1, vertical_spacing=0.12)

for idx, year in enumerate(years):
    # type 'A'
    df_product_a_A = df_product_a.loc[((df_product_a.year == year) & (df_product_a.type == 'A')), ['total_vol', 'location', 'type']]
    # grouped by locations
    _A = df_product_a_A.groupby('location')['total_vol'].sum()
    # type 'C'
    df_product_a_C = df_product_a.loc[((df_product_a.year == year) & (df_product_a.type == 'C')), ['total_vol', 'location', 'type']]
    # grouped by locations
    _C = df_product_a_C.groupby('location')['total_vol'].sum()
    
    fig.add_trace(go.Bar(name='Type A', x=_A.index, y=_A), idx + 1, 1)
    fig.add_trace(go.Bar(name='Type C', x=_C.index, y=_C), idx + 1, 1)

    # plotting stacked bar chart
    fig.update_layout(barmode='stack', height=1500)

plot(fig, filename='total_vol_by_location_type.html')
# Out:
# 'total_vol_by_location_type.html'
